# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 73082, done.
# remote: Counting objects: 100% (3052/3052), done.
# remote: Compressing objects: 100% (2855/2855), done.
# remote: Total 73082 (delta 209), reused 3029 (delta 190), pack-reused 70030
# Receiving objects: 100% (73082/73082), 126.34 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (211/211), done.
# Updating files: 100% (5867/5867), done.

# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
dataframe = read_csv("machine_learning/Classification/bodyPerformance.csv")
dataframe.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
le = LabelEncoder()
dataframe['gender'] = le.fit_transform(dataframe['gender'])
data = dataframe.loc[:, ['age', 'gender', 'height_cm', 'weight_kg',
       'body fat_%', 'diastolic', 'systolic', 'gripForce', 'sit and bend forward_cm',
       'sit-ups counts', 'broad jump_cm']]
labels = dataframe['class']

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
features = len(dataframe. columns)
values = []
criterions = ("gini","entropy")
for i in range(30,100):
  for x in range(1,15):
    for y in criterions:
      model = RandomForestClassifier(n_estimators=i, random_state=42,criterion=y,max_depth=x)
      model.fit(trainData, trainLabels)
      val = f"Result {i} {x} {y}"
      val1 =(model.score(trainData, trainLabels))
      val2 =(model.score(testData, testLabels))
      predictions = model.predict(testData)
      # print(classification_report(testLabels, predictions))
      if model.score(trainData, trainLabels) >= 0.74 and model.score(testData, testLabels) >= 0.74:
        values.append((val, val1, val2))
print(values)
print(max(values))
# Out:
# [('Result 30 14 entropy', 0.9674432497013142, 0.740519558077038), ('Result 31 14 entropy', 0.9672441258462764, 0.7402209614810391), ('Result 32 14 entropy', 0.9672441258462764, 0.7423111376530308), ('Result 33 12 entropy', 0.9206491437674234, 0.7414153478650344), ('Result 33 13 entropy', 0.9502190362405416, 0.7408181546730367), ('Result 33 14 entropy', 0.9670450019912386, 0.742012541057032), ('Result 34 12 entropy', 0.9200517722023098, 0.743505524037026), ('Result 34 13 entropy', 0.9504181600955794, 0.7411167512690355), ('Result 34 14 entropy', 0.9673436877737953, 0.740519558077038), ('Result 35 12 entropy', 0.9212465153325369, 0.746491489997014), ('Result 35 13 entropy', 0.949721226602947, 0.7426097342490295), ('Result 35 14 entropy', 0.9671445639187575, 0.7411167512690355), ('Result 36 12 entropy', 0.9207487056949423, 0.7441027172290235), ('Result 36 13 entropy', 0.9498207885304659, 0.7429083308450284), ('Result 36 14 entropy', 0.9673436877737953, 0.743505524037026), ('Result 37 12 entropy', 0.9207487056949423, 0.7458942968050164), ('Result 37 13 gini', 0.9348864994026285, 0.740519558077038), ('Result 37 13 entropy', 0.9503185981680605, 0.7458942968050164), ('Result 37 14